# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches
import numpy as np
from PIL import Image
# %matplotlib inline

# %%
def plot_single(im_path, coords_path, idx=0, force_square=False):
    """
    coords: [x1, y1, x2, y2, x3, y3, x4, y4]
    """
    with open(coords_path, 'r') as f:
        l = f.read().split("\n")
        pix = [float(x) for x in l[idx].split(',')]
    im = Image.open(im_path)
    plt.subplots(1)
    plt.imshow(im)
    if (force_square):
        X, Y = pix[::2], pix[1::2]
        pix = [min(X), min(Y), max(X),  max(Y)]
        plt.plot([pix[0], pix[2], pix[2], pix[0], pix[0], ],
                 [pix[1], pix[1], pix[3], pix[3], pix[1], ], 'ro-', lw=2)
    elif (len(pix) == 8):
        plt.plot(pix[::2] + [pix[0]], pix[1::2] + [pix[1]], 'ro-', lw=2)
    else:
        plt.plot([pix[0], pix[2], pix[2], pix[0], pix[0], ],
                 [pix[1], pix[1], pix[3], pix[3], pix[1], ], 'ro-', lw=2)
    plt.show()
    return plt

# %%
with open("/home/zabulskyy/Datasets/vot2016/bag/groundtruth.txt", 'r') as f:
    l = f.read().split("\n")
pix = [float(x) for x in l[0].split(',')]
pix
# Out:
# [334.02, 128.36, 438.19, 188.78, 396.39, 260.83, 292.23, 200.41]

# %%
im = Image.open("/home/zabulskyy/Datasets/vot2016/bag/00000001.jpg")
plt.imshow(im)
width, height = im.size
percentile = 1/4
pix = [percentile * width, percentile * height,
        (1-percentile)*width,  (1-percentile)*height]
plt.plot([pix[0], pix[2], pix[2], pix[0], pix[0], ],
                 [pix[1], pix[1], pix[3], pix[3], pix[1], ], 'ro-', lw=2)
plt.show()

# rect = patches.Rectangle((10, 10, 10, 10),linewidth=2,edgecolor='r',facecolor=(1,0,0, .3))
# ax.add_patch(rect)
